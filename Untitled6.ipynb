# %% [markdown]
# <a href="https://colab.research.google.com/github/sarika178btcse25-netizen/ML-and-GenAI-with-Python-2026/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# 1. Load the dataset
# Replace 'agricultural_yield_dataset.csv' with your actual file path if needed
df = pd.read_csv('agriculture_yield_dataset.csv')

# --- Q1. Dataset Overview ---

# A. How many rows and columns are present?
rows, columns = df.shape
print(f"Number of rows: {rows}")
print(f"Number of columns: {columns}\n")

# B. What are the names of all columns?
print("Column Names:")
print(list(df.columns))
print()

# C. Display the first 10 records.
print("First 10 Records:")
print(df.head(10))
# Out:
# Number of rows: 1500
# Number of columns: 8
#
# Column Names:
# ['rainfall_mm', 'temperature_c', 'fertilizer_kg', 'irrigation_hours', 'soil_ph', 'crop_type', 'soil_type', 'yield_ton_per_hectare']
#
# First 10 Records:
#    rainfall_mm  temperature_c  fertilizer_kg  irrigation_hours  soil_ph  \
# 0        588.6           18.6          242.4               6.5      6.5
# 1        772.8           34.6          247.2              10.0      6.5
# 2        970.9           36.3          168.4               7.3      6.4
# 3        611.7           19.0          121.7               3.7      6.0
# 4        696.1           29.6          184.6               5.1      6.1
# 5        831.9           28.0          190.3               2.1      6.1
# 6       1023.8           32.0          108.5               6.9      6.2
# 7       1142.4           18.4          241.9               4.1      7.3
# 8        810.4           36.4          164.8               9.9      6.5
# ...

# %%
import pandas as pd


df = pd.read_csv('agriculture_yield_dataset.csv')




print("--- Data Types of Each Column ---")
print(df.dtypes)
print("\n" + "="*40 + "\n")
print("--- Missing Values Summary (Count per column) ---")
missing_counts = df.isnull().sum()
print(missing_counts)
print("\n" + "="*40 + "\n")

missing_columns = missing_counts[missing_counts > 0]

if not missing_columns.empty:
    print("--- Affected Columns with Missing Values ---")
    for col, count in missing_columns.items():
        print(f"Column '{col}' has {count} missing value(s).")
else:
    print("No missing values found in any column of the dataset.")
# Out:
# --- Data Types of Each Column ---
# rainfall_mm              float64
# temperature_c            float64
# fertilizer_kg            float64
# irrigation_hours         float64
# soil_ph                  float64
# crop_type                 object
# soil_type                 object
# yield_ton_per_hectare    float64
# dtype: object
#
# ...
#
# --- Missing Values Summary (Count per column) ---
# rainfall_mm              0
# temperature_c            0
# fertilizer_kg            0
# irrigation_hours         0
# soil_ph                  0
# crop_type                0
# soil_type                0
# yield_ton_per_hectare    0
# dtype: int64
#
# ...
#
# No missing values found in any column of the dataset.

# %%
import pandas as pd

# Load your agricultural dataset
df = pd.read_csv('agriculture_yield_dataset.csv')

# --- Q3. Descriptive Statistics ---

# 1. Generate summary statistics for all numerical features
# (This includes count, mean, std, min, 25%, 50%, 75%, and max)
numerical_summary = df.describe()
print("--- Summary Statistics ---")
print(numerical_summary)
print("\n" + "="*50 + "\n")

# Extract means and standard deviations, excluding the row count
means = numerical_summary.loc['mean']
stds = numerical_summary.loc['std']

# 2. Find which feature has the highest mean value
highest_mean_feature = means.idxmax()
highest_mean_value = means.max()

print(f"Feature with the highest mean value: '{highest_mean_feature}' ({highest_mean_value:.2f})")

# 3. Find which feature has the highest standard deviation
highest_std_feature = stds.idxmax()
highest_std_value = stds.max()

print(f"Feature with the highest standard deviation: '{highest_std_feature}' ({highest_std_value:.2f})")
# Out:
# --- Summary Statistics ---
#        rainfall_mm  temperature_c  fertilizer_kg  irrigation_hours  \
# count  1500.000000    1500.000000    1500.000000       1500.000000
# mean    754.054667      27.749467     148.744067          5.403267
# std     255.097216       5.758101      56.990279          2.584329
# min     300.200000      18.000000      50.300000          1.000000
# 25%     536.175000      22.600000      98.600000          3.200000
# 50%     761.200000      27.700000     146.850000          5.400000
# 75%     964.375000      32.600000     196.575000          7.600000
# max    1200.000000      38.000000     249.900000         10.000000
#
#            soil_ph  yield_ton_per_hectare
# count  1500.000000            1500.000000
# mean      6.759133               5.028793
# std       0.719742               0.968282
# min       5.500000               2.090000
# 25%       6.100000               4.337500
# 50%       6.800000               5.010000
# ...

# %%
# ==========================================
# Q4 & Q5 - Exploratory Data Analysis (EDA)
# ==========================================

# Import Libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load Dataset
df = pd.read_csv("agriculture_yield_dataset.csv")

# Display first 5 rows
print("First 5 Rows of Dataset:")
display(df.head())

# ------------------------------------------
# Q4. Distribution Analysis
# ------------------------------------------

columns = [
    "rainfall_mm",
    "temperature_c",
    "fertilizer_kg",
    "yield_ton_per_hectare"
]

for col in columns:
    plt.figure(figsize=(7,5))
    sns.histplot(df[col], bins=20, kde=True, color="skyblue")
    plt.title(f"Histogram of {col}")
    plt.xlabel(col)
    plt.ylabel("Frequency")
    plt.grid(True)
    plt.show()

# ------------------------------------------
# Q5. Crop Type Analysis
# ------------------------------------------

print("\nNumber of Records for Each Crop Type:\n")
crop_counts = df["crop_type"].value_counts()
print(crop_counts)

# Count Plot
plt.figure(figsize=(8,5))
sns.countplot(x="crop_type", data=df)

plt.title("Count Plot of Crop Types")
plt.xlabel("Crop Type")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.grid(axis='y')

plt.show()

# Most Frequent Crop
most_frequent = crop_counts.idxmax()
count = crop_counts.max()

print("\nMost Frequent Crop Type:", most_frequent)
print("Number of Records:", count)
# Out:
# First 5 Rows of Dataset:
#    rainfall_mm  temperature_c  fertilizer_kg  irrigation_hours  soil_ph  \
# 0        588.6           18.6          242.4               6.5      6.5
# 1        772.8           34.6          247.2              10.0      6.5
# 2        970.9           36.3          168.4               7.3      6.4
# 3        611.7           19.0          121.7               3.7      6.0
# 4        696.1           29.6          184.6               5.1      6.1
#
#   crop_type soil_type  yield_ton_per_hectare
# 0     Maize     Loamy                   5.92
# 1     Maize     Sandy                   6.24
# 2     Wheat     Sandy                   4.77
# 3     Maize     Loamy                   4.04
# 4    Cotton      Clay                   5.17
# Number of Records for Each Crop Type:
#
# crop_type
# Cotton     311
# Soybean    306
# Wheat      303
# Rice       293
# Maize      287
# Name: count, dtype: int64
# Most Frequent Crop Type: Cotton
# Number of Records: 311

# %%
# ==========================================
# Q6. Soil Type Analysis
# ==========================================

# Frequency of each soil type
print("Frequency of Each Soil Type:\n")
soil_counts = df["soil_type"].value_counts()
print(soil_counts)

# Count Plot
plt.figure(figsize=(8,5))
sns.countplot(x="soil_type", data=df)

plt.title("Count Plot of Soil Types")
plt.xlabel("Soil Type")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.grid(axis='y')

plt.show()

# Most Common Soil Type
most_common_soil = soil_counts.idxmax()
count = soil_counts.max()

print("\nMost Common Soil Type:", most_common_soil)
print("Number of Records:", count)
# Out:
# Frequency of Each Soil Type:
#
# soil_type
# Clay     534
# Sandy    492
# Loamy    474
# Name: count, dtype: int64
# Most Common Soil Type: Clay
# Number of Records: 534

# %%
# ==========================================
# Q7. Yield Distribution
# ==========================================

plt.figure(figsize=(7,5))

sns.histplot(df["yield_ton_per_hectare"],
             bins=20,
             kde=True,
             color="green")

plt.title("Histogram of Yield per Hectare")
plt.xlabel("Yield (ton/hectare)")
plt.ylabel("Frequency")
plt.grid(True)

plt.show()

# %%
# ==========================================
# Q8. Scatter Plot Analysis
# ==========================================

# Rainfall vs Yield
plt.figure(figsize=(7,5))

sns.scatterplot(x="rainfall_mm",
                y="yield_ton_per_hectare",
                data=df)

plt.title("Rainfall vs Yield")
plt.xlabel("Rainfall (mm)")
plt.ylabel("Yield (ton/hectare)")
plt.grid(True)

plt.show()


# Fertilizer vs Yield
plt.figure(figsize=(7,5))

sns.scatterplot(x="fertilizer_kg",
                y="yield_ton_per_hectare",
                data=df)

plt.title("Fertilizer vs Yield")
plt.xlabel("Fertilizer (kg)")
plt.ylabel("Yield (ton/hectare)")
plt.grid(True)

plt.show()

# %%
# ==========================================
# Q9. Correlation Analysis
# ==========================================

import matplotlib.pyplot as plt
import seaborn as sns

# Select only numerical columns
numerical_df = df.select_dtypes(include=['int64', 'float64'])

# Correlation Matrix
correlation_matrix = numerical_df.corr()

print("Correlation Matrix:")
display(correlation_matrix)

# Heatmap
plt.figure(figsize=(8,6))

sns.heatmap(correlation_matrix,
            annot=True,
            cmap="coolwarm",
            fmt=".2f")

plt.title("Correlation Heatmap")
plt.show()

# Top 3 Features Correlated with Yield
yield_corr = correlation_matrix["yield_ton_per_hectare"].drop("yield_ton_per_hectare")

top3 = yield_corr.abs().sort_values(ascending=False).head(3)

print("\nTop 3 Features Most Correlated with Yield:")
print(top3)
# Out:
# Correlation Matrix:
#                        rainfall_mm  temperature_c  fertilizer_kg  \
# rainfall_mm               1.000000       0.026721       0.002558
# temperature_c             0.026721       1.000000       0.037468
# fertilizer_kg             0.002558       0.037468       1.000000
# irrigation_hours          0.010877       0.007114      -0.010497
# soil_ph                   0.006916       0.001513       0.010001
# yield_ton_per_hectare     0.553704      -0.022559       0.278043
#
#                        irrigation_hours   soil_ph  yield_ton_per_hectare
# rainfall_mm                    0.010877  0.006916               0.553704
# temperature_c                  0.007114  0.001513              -0.022559
# fertilizer_kg                 -0.010497  0.010001               0.278043
# irrigation_hours               1.000000  0.009307               0.542664
# soil_ph                        0.009307  1.000000               0.024412
# ...

# %%
# ==========================================
# Q10. Group-Based Analysis
# ==========================================

# Average Yield by Crop Type
crop_avg = df.groupby("crop_type")["yield_ton_per_hectare"].mean()

print("Average Yield for Each Crop Type:\n")
print(crop_avg)

print("\n")

# Average Yield by Soil Type
soil_avg = df.groupby("soil_type")["yield_ton_per_hectare"].mean()

print("Average Yield for Each Soil Type:\n")
print(soil_avg)

# Highest Average Yield Crop
best_crop = crop_avg.idxmax()
best_crop_yield = crop_avg.max()

# Highest Average Yield Soil
best_soil = soil_avg.idxmax()
best_soil_yield = soil_avg.max()

print("\nCrop with Highest Average Yield:")
print(best_crop, "-", round(best_crop_yield,2))

print("\nSoil Type with Highest Average Yield:")
print(best_soil, "-", round(best_soil_yield,2))
# Out:
# Average Yield for Each Crop Type:
#
# crop_type
# Cotton     4.607299
# Maize      4.897143
# Rice       5.494744
# Soybean    5.173431
# Wheat      4.989472
# Name: yield_ton_per_hectare, dtype: float64
#
#
# Average Yield for Each Soil Type:
#
# soil_type
# Clay     5.134326
# Loamy    5.366519
# Sandy    4.588882
# Name: yield_ton_per_hectare, dtype: float64
#
# Crop with Highest Average Yield:
# Rice - 5.49
#
# Soil Type with Highest Average Yield:
# Loamy - 5.37

# %%
# ==========================================
# Q11. Feature Encoding
# ==========================================

# Identify categorical columns
categorical_columns = df.select_dtypes(include=['object']).columns

print("Categorical Columns:")
print(list(categorical_columns))

# One-Hot Encoding
encoded_df = pd.get_dummies(df,
                            columns=categorical_columns,
                            dtype=int)

print("\nFirst Five Rows of Encoded Dataset:")
display(encoded_df.head())
# Out:
# Categorical Columns:
# ['crop_type', 'soil_type']
#
# First Five Rows of Encoded Dataset:
#    rainfall_mm  temperature_c  fertilizer_kg  irrigation_hours  soil_ph  \
# 0        588.6           18.6          242.4               6.5      6.5
# 1        772.8           34.6          247.2              10.0      6.5
# 2        970.9           36.3          168.4               7.3      6.4
# 3        611.7           19.0          121.7               3.7      6.0
# 4        696.1           29.6          184.6               5.1      6.1
#
#    yield_ton_per_hectare  crop_type_Cotton  crop_type_Maize  crop_type_Rice  \
# 0                   5.92                 0                1               0
# 1                   6.24                 0                1               0
# 2                   4.77                 0                0               0
# 3                   4.04                 0                1               0
# ...

# %%
# ==========================================
# Q12. Feature Selection
# ==========================================

# Input Features (X)
X = encoded_df.drop("yield_ton_per_hectare", axis=1)

# Target Variable (y)
y = encoded_df["yield_ton_per_hectare"]

print("Target Variable:")
print("yield_ton_per_hectare")

print("\nInput Features (First 5 Rows):")
display(X.head())

print("\nTarget Variable (First 5 Rows):")
display(y.head())
# Out:
# Target Variable:
# yield_ton_per_hectare
#
# Input Features (First 5 Rows):
#    rainfall_mm  temperature_c  fertilizer_kg  irrigation_hours  soil_ph  \
# 0        588.6           18.6          242.4               6.5      6.5
# 1        772.8           34.6          247.2              10.0      6.5
# 2        970.9           36.3          168.4               7.3      6.4
# 3        611.7           19.0          121.7               3.7      6.0
# 4        696.1           29.6          184.6               5.1      6.1
#
#    crop_type_Cotton  crop_type_Maize  crop_type_Rice  crop_type_Soybean  \
# 0                 0                1               0                  0
# 1                 0                1               0                  0
# 2                 0                0               0                  0
# 3                 0                1               0                  0
# 4                 1                0               0                  0
#
# ...

# %%
# ==========================================
# Q13. Train-Test Split
# ==========================================

from sklearn.model_selection import train_test_split

# Split the data into 80% training and 20% testing
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42
)

print("Shape of X_train:", X_train.shape)
print("Shape of X_test :", X_test.shape)
print("Shape of y_train:", y_train.shape)
print("Shape of y_test :", y_test.shape)
# Out:
# Shape of X_train: (1200, 13)
# Shape of X_test : (300, 13)
# Shape of y_train: (1200,)
# Shape of y_test : (300,)

# %%
# ==========================================
# Q14. Linear Regression Model
# ==========================================

from sklearn.linear_model import LinearRegression

# Create Model
model = LinearRegression()

# Train Model
model.fit(X_train, y_train)

# Display Intercept
print("Intercept:")
print(model.intercept_)

# Display Coefficients
coefficients = pd.DataFrame({
    "Feature": X.columns,
    "Coefficient": model.coef_
})

print("\nModel Coefficients:")
display(coefficients)

# Feature with Highest Positive Coefficient
highest_feature = coefficients.loc[coefficients["Coefficient"].idxmax()]

print("\nFeature with Highest Positive Coefficient:")
print(highest_feature)
# Out:
# Intercept:
# 1.9111026182800726
#
# Model Coefficients:
#               Feature  Coefficient
# 0         rainfall_mm     0.002035
# 1       temperature_c    -0.009175
# 2       fertilizer_kg     0.004978
# 3    irrigation_hours     0.198327
# 4             soil_ph     0.004901
# 5    crop_type_Cotton    -0.386623
# 6     crop_type_Maize    -0.147693
# 7      crop_type_Rice     0.477369
# 8   crop_type_Soybean     0.095096
# 9     crop_type_Wheat    -0.038149
# 10     soil_type_Clay     0.062653
# 11    soil_type_Loamy     0.365627
# 12    soil_type_Sandy    -0.428280
# Feature with Highest Positive Coefficient:
# Feature        crop_type_Rice
# Coefficient          0.477369
# Name: 7, dtype: object
